# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv("uci breast cancer dataset.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df = df.drop(['Unnamed: 32', 'id'], axis=1)

# %%
df.isna().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df['diagnosis'] = df['diagnosis'].replace({"B":1, "M":0})
# Out:
# C:\Users\MD Maruf\AppData\Local\Temp\ipykernel_13388\2729372190.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['diagnosis'] = df['diagnosis'].replace({"B":1, "M":0})

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          0        17.99         10.38          122.80     1001.0
# 1          0        20.57         17.77          132.90     1326.0
# 2          0        19.69         21.25          130.00     1203.0
# 3          0        11.42         20.38           77.58      386.1
# 4          0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
x = df.drop(['diagnosis'], axis=1)
y = df[['diagnosis']]

# %%
st = StandardScaler()
for col in x.columns:
    x[col] = st.fit_transform(x[[col]])

# %%
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# # Before PCA

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, random_state=42, test_size=.2)

# %%
ada = AdaBoostClassifier(n_estimators=100)
ada_model = ada.fit(xtrain, ytrain)
print(f'Train score: {ada_model.score(xtrain, ytrain)}')
print(f'Test score: {ada_model.score(xtest, ytest)}')
ada_pred = ada_model.predict(xtest)
ada_cm = confusion_matrix(ytest, ada_pred)
print(f'confusion_matrix:\n{ada_cm}')
ada_ac = accuracy_score(ytest, ada_pred)
print(f'accuracy: {ada_ac}')
# Out:
# c:\Users\MD Maruf\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Train score: 1.0
# Test score: 0.9736842105263158
# confusion_matrix:
# [[41  2]
#  [ 1 70]]
# accuracy: 0.9736842105263158

# %%
log = LogisticRegression()
log_model = log.fit(xtrain, ytrain)
print(f'Train Score: {log_model.score(xtrain, ytrain)}')
print(f'Test Score: {log_model.score(xtest, ytest)}')
log_pred = log_model.predict(xtest)
print(f'confusion_matrix:\n{confusion_matrix(ytest, log_pred)}')
print(f'Accuracy: {accuracy_score(ytest, log_pred)}')
# Out:
# Train Score: 0.9868131868131869
# Test Score: 0.9736842105263158
# confusion_matrix:
# [[41  2]
#  [ 1 70]]
# Accuracy: 0.9736842105263158
# c:\Users\MD Maruf\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # Feature Extraction

# %%
pca = PCA(n_components=5)
x_pca = pca.fit_transform(x)
x_pca
# Out:
# array([[ 9.19283683,  1.94858307, -1.12316616, -3.6337309 ,  1.19511012],
#        [ 2.3878018 , -3.76817174, -0.52929269, -1.11826386, -0.62177498],
#        [ 5.73389628, -1.0751738 , -0.55174759, -0.91208267,  0.1770859 ],
#        ...,
#        [ 1.25617928, -1.90229671,  0.56273053,  2.08922702, -1.80999133],
#        [10.37479406,  1.67201011, -1.87702933,  2.35603113,  0.03374193],
#        [-5.4752433 , -0.67063679,  1.49044308,  2.29915714,  0.18470331]],
#       shape=(569, 5))

# %%
explained_var = pca.explained_variance_ratio_
print(f"Explain Variance Ratio: {explained_var}")
cumsum_var = np.cumsum(explained_var)
print(f"Cumulative variance: {cumsum_var}")
# Out:
# Explain Variance Ratio: [0.44272026 0.18971182 0.09393163 0.06602135 0.05495768]
# Cumulative variance: [0.44272026 0.63243208 0.72636371 0.79238506 0.84734274]

# %%
#scree plot
plt.figure(figsize=(8,5))
plt.plot(range(1, len(explained_var)+1), explained_var, marker="o", linestyle="-.")
plt.title("Scree Plot")
plt.xlabel("Principal Component")
plt.ylabel("Explained Variance Ratio")
plt.xticks(range(1, len(explained_var)+1))
plt.show()

# %%
#Cumulative variance plot
plt.figure(figsize=(8,5))
plt.plot(range(1, len(cumsum_var)+1), cumsum_var, marker='*', linestyle=":", color='green')
plt.title("Cumulative Variance Explained")
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.xticks(range(1, len(cumsum_var)+1))
plt.axhline(y=0.95, linestyle='--', color="red")
plt.show()

# %% [markdown]
# # After PCA

# %%
x_train, x_test, y_train, y_test = train_test_split(x_pca, y, random_state=42, test_size=0.2)

# %%
ada = AdaBoostClassifier(n_estimators=100)
ada_model_a = ada.fit(x_train, y_train)
print(f'Train score: {ada_model_a.score(x_train, y_train)}')
print(f'Test score: {ada_model_a.score(x_test, y_test)}')
ada_pred_a = ada_model_a.predict(x_test)
ada_cm_a = confusion_matrix(y_test, ada_pred_a)
print(f'confusion_matrix:\n{ada_cm_a}')
ada_ac_a = accuracy_score(y_test, ada_pred_a)
print(f'accuracy: {ada_ac_a}')
# Out:
# c:\Users\MD Maruf\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Train score: 1.0
# Test score: 0.9736842105263158
# confusion_matrix:
# [[42  1]
#  [ 2 69]]
# accuracy: 0.9736842105263158

# %%
log = LogisticRegression()
log_model_a = log.fit(x_train, y_train)
print(f'Train Score: {log_model_a.score(x_train, y_train)}')
print(f'Test Score: {log_model_a.score(x_test, y_test)}')
log_pred_a = log_model_a.predict(x_test)
print(f'confusion_matrix:\n{confusion_matrix(y_test, log_pred_a)}')
print(f'Accuracy: {accuracy_score(ytest, log_pred_a)}')
# Out:
# Train Score: 0.9736263736263736
# Test Score: 0.9824561403508771
# confusion_matrix:
# [[42  1]
#  [ 1 70]]
# Accuracy: 0.9824561403508771
# c:\Users\MD Maruf\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
