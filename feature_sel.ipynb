# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("uci breast cancer dataset.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df = df.drop(['Unnamed: 32'], axis=1)

# %%
df['diagnosis'] = df['diagnosis'].replace({"M":1, "B":0})

# %%
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df = df.drop(['id'], axis=1)

# %%
df1 = df.copy()

# %%
x = df.drop(['diagnosis'], axis=1)
y = df[['diagnosis']]

# %% [markdown]
# ## Chi2 (filter method to select feature)

# %%
chi2_selector = SelectKBest(score_func=chi2, k=10)
chi2_selector.fit(x, y)
# Out:
# SelectKBest(score_func=<function chi2 at 0x000001E47FC1D080>)

# %%
scores = pd.DataFrame({'Feature':x.columns, "Chi2_score": chi2_selector.scores_})
scores = scores.sort_values(by='Chi2_score', ascending=False)
print(scores)
# Out:
#                     Feature     Chi2_score
# 23               area_worst  112598.431564
# 3                 area_mean   53991.655924
# 13                  area_se    8758.504705
# 22          perimeter_worst    3665.035416
# 2            perimeter_mean    2011.102864
# 20             radius_worst     491.689157
# 0               radius_mean     266.104917
# 12             perimeter_se     250.571896
# 21            texture_worst     174.449400
# 1              texture_mean      93.897508
# 26          concavity_worst      39.516915
# 10                radius_se      34.675247
# 6            concavity_mean      19.712354
# 25        compactness_worst      19.314922
# 27     concave points_worst      13.485419
# 7       concave points_mean      10.544035
# 5          compactness_mean       5.403075
# 28           symmetry_worst       1.298861
# 16             concavity_se       1.044718
# 15           compactness_se       0.613785
# 24         smoothness_worst       0.397366
# ...

# %%
selected_feature = x.columns[chi2_selector.get_support()]
print(f'\n Selected Feature:{list(selected_feature)}')
# Out:
#  Selected Feature:['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'perimeter_se', 'area_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst']

# %%
df['diagnosis'] = df['diagnosis'].replace({"M":1, "B":1})

# %% [markdown]
# # without selecdet feature

# %%
X = df.drop(['diagnosis'], axis=1)
Y = df[['diagnosis']]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
log_b = LogisticRegression(max_iter=5000)
log_model_b = log_b.fit(x_train, y_train)
print(f'Train Score:{log_model_b.score(x_train, y_train)}')
print(f'Test Score: {log_model_b.score(x_test, y_test)}')
log_predict_b = log_model_b.predict(x_test)
log_cm_b = confusion_matrix(y_test, log_predict_b)
print(f'confusion_matrix:\n {log_cm_b}')
print(f'accuracy_score: {accuracy_score(y_test, log_predict_b)}')
# Out:
# Train Score:0.9626373626373627
# Test Score: 0.956140350877193
# confusion_matrix:
#  [[70  1]
#  [ 4 39]]
# accuracy_score: 0.956140350877193

# %%
random_b = RandomForestClassifier(n_estimators=100)
random_model_b = random_b.fit(x_train, y_train)
print(f'Train Score:{random_model_b.score(x_train, y_train)}')
print(f'Test Score: {random_model_b.score(x_test, y_test)}')
random_predict_b = random_model_b.predict(x_test)
random_cm_b = confusion_matrix(y_test, random_predict_b)
print(f'confusion_matrix:\n {random_cm_b}')
print(f'accuracy_score: {accuracy_score(y_test, random_predict_b)}')
# Out:
# Train Score:1.0
# Test Score: 0.9649122807017544
# confusion_matrix:
#  [[70  1]
#  [ 3 40]]
# accuracy_score: 0.9649122807017544

# %%
x_new = df[selected_feature]
y = df[['diagnosis']]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x_new, y, test_size=0.2, random_state=42)

# %% [markdown]
# # with Selected Feature

# %%
log = LogisticRegression(max_iter=5000)
log_model = log.fit(xtrain, ytrain)
print(f'Train Score:{log_model.score(xtrain, ytrain)}')
print(f'Test Score: {log_model.score(xtest, ytest)}')
log_predict = log_model.predict(xtest)
cm = confusion_matrix(ytest, log_predict)
print(f'confusion_matrix:\n {cm}')
print(f'accuracy_score: {accuracy_score(ytest, log_predict)}')
# Out:
# Train Score:0.945054945054945
# Test Score: 0.9649122807017544
# confusion_matrix:
#  [[70  1]
#  [ 3 40]]
# accuracy_score: 0.9649122807017544

# %%
random = RandomForestClassifier(n_estimators=100)
random_model= random.fit(xtrain, ytrain)
print(f'Train Score:{random_model.score(xtrain, ytrain)}')
print(f'Test Score: {random_model.score(xtest, ytest)}')
random_predict = random_model.predict(xtest)
random_cm = confusion_matrix(ytest, random_predict)
print(f'confusion_matrix:\n {random_cm}')
print(f'accuracy_score: {accuracy_score(ytest, random_predict)}')
# Out:
# Train Score:1.0
# Test Score: 0.9649122807017544
# confusion_matrix:
#  [[70  1]
#  [ 3 40]]
# accuracy_score: 0.9649122807017544

# %% [markdown]
# # RFE (Recursive Feature Elimination)
# # Wrapper Method to select feature

# %%
from sklearn.feature_selection import RFE

# %%
a = df1.drop(['diagnosis'], axis=1)
b = df1[['diagnosis']]

# %%
a_train, a_test, b_train, b_test = train_test_split(a, b, test_size=0.2, random_state=42)

# %%
log_all = LogisticRegression(max_iter=5000)
model_all = log_all.fit(a_train, b_train)
print(model_all.score(a_train, b_train))
print(model_all.score(a_test, b_test))
# Out:
# 0.9626373626373627
# 0.956140350877193

# %%
logistic = LogisticRegression(max_iter=5000)
rfe = RFE(logistic, n_features_to_select=5)
rfe
# Out:
# RFE(estimator=LogisticRegression(max_iter=5000), n_features_to_select=5)

# %%
rfe.fit(a_train, b_train)
# Out:
# RFE(estimator=LogisticRegression(max_iter=5000), n_features_to_select=5)

# %%
selected_feature = a.columns[rfe.support_]
selected_feature
# Out:
# Index(['radius_mean', 'texture_se', 'radius_worst', 'compactness_worst',
#        'concavity_worst'],
#       dtype='object')

# %%
a_train_selected = a_train[selected_feature]
a_test_selected = a_test[selected_feature]

# %%
log_sel = LogisticRegression(max_iter=5000)
model_sel = log_sel.fit(a_train_selected, b_train)
print(model_sel.score(a_train_selected, b_train))
print(model_sel.score(a_test_selected, b_test))
model_sel_pred = model_sel.predict(a_test_selected)
print(f"accuracy_score: {accuracy_score(b_test, model_sel_pred)}")
# Out:
# 0.9494505494505494
# 0.9736842105263158
# accuracy_score: 0.9736842105263158
